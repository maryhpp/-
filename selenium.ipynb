# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options

# %%
driver = webdriver.Chrome()

# %%
driver.get('https://www.baidu.com')

# %%
driver.page_source[:1000]
# Out:
# '<html><head><script type="text/javascript" charset="utf-8" src="https://dss0.bdstatic.com/5aV1bjqh_Q23odCf/static/superman/js/components/guide-13c605998f.js"></script><script type="text/javascript" charset="utf-8" src="https://dss0.bdstatic.com/5aV1bjqh_Q23odCf/static/superman/js/components/qrcode-da919182da.js"></script><script type="text/javascript" charset="utf-8" src="https://dss0.bdstatic.com/5aV1bjqh_Q23odCf/static/superman/js/super_load-a97cbd2188.js"></script><script type="text/javascript" charset="utf-8" src="https://dss0.bdstatic.com/5aV1bjqh_Q23odCf/static/superman/js/components/tips-e2ceadd14d.js"></script><meta http-equiv="Content-Type" content="text/html;charset=utf-8"><meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1"><meta content="always" name="referrer"><meta name="theme-color" content="#2932e1"><meta name="description" content="全球最大的中文搜索引擎、致力于让网民更便捷地获取信息，找到所求。百度超过千亿的中文网页数据库，可以瞬间找到相关的搜索结果。"><link rel="shortcut icon" href="/favicon.ico" type="image/x-icon
# ...

# %%
driver.find_element_by_id('kw')
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="e30f986bb2171da2860c971a6ff16d18", element="ea65fc99-4fd5-48d4-9090-af6eff3a7c60")>

# %%
driver.find_element_by_class_name('s_ipt')
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="10ebfd83205463cd8a046a3e6023564c", element="06c62a48-b710-4b3d-8179-db5ad2171212")>

# %%
driver.find_element_by_xpath('//input[@id="kw"]')   #区别他是一个列表，列表中找到所有符合元素
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="10ebfd83205463cd8a046a3e6023564c", element="06c62a48-b710-4b3d-8179-db5ad2171212")>

# %%
driver.find_element_by_xpath('//input[@class="s_ipt"]')
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="10ebfd83205463cd8a046a3e6023564c", element="06c62a48-b710-4b3d-8179-db5ad2171212")>

# %%
driver.find_element_by_id('su')
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="10ebfd83205463cd8a046a3e6023564c", element="1e458371-7e07-48b2-a38c-a3af77d92d39")>

# %%
driver.find_element_by_id('su').get_attribute('value')
# Out:
# '百度一下'

# %%
driver.find_element_by_xpath('//div[@id="s-top-left"]')
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="10ebfd83205463cd8a046a3e6023564c", element="c7277812-3baa-44c4-90e4-898eea66e1de")>

# %%
ele1=driver.find_element_by_xpath('//div[@id="s-top-left"]/a[1]')

# %%
ele1.text
# Out:
# '新闻'

# %%
driver.find_element_by_id('kw').send_keys('python')

# %%
driver.find_element_by_id('kw').send_keys('python风景')

# %%
driver.find_element_by_id('kw').clear()

# %%
driver.find_element_by_id('kw').send_keys('python')

# %%
driver.find_element_by_id('su').click()

# %%
driver.execute_script('window.scrollTo(0,document.body.scrollHeight)')

# %%
driver.get('https://www.douban.com')

# %%
driver.find_element_by_xpath('/html/body/div[1]/div[1]/ul[1]/li[1]')
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="e30f986bb2171da2860c971a6ff16d18", element="170d4b74-cb3e-4bd9-9a64-94c7666c8bce")>

# %%
driver.find_element_by_xpath('/html/body/div[1]/div[1]/ul[1]/li[2]').click()

# %%
driver.find_element_by_xpath('//div[@class="login"]')
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="e30f986bb2171da2860c971a6ff16d18", element="73c09f0f-4a28-47d1-b105-31df24a4b01a")>

# %%
ele1 = driver.find_element_by_xpath('//div[@class="login"]')

# %%
driver.switch_to.frame(driver.find_element_by_tag_name('iframe'))

# %%
driver.find_element_by_xpath('//ul[@class="tab-start"]/li[2]').click()

# %%
driver.find_element_by_id('username').send_keys('hello')

# %%
driver.find_element_by_id('password').send_keys('123456')

# %%
driver.find_element_by_class_name('account-form-field-submit').click()

# %%
driver.switch_to_default_content() #切换到主文档
# Out:
# D:\Anaconda3\envs\crawler\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: use driver.switch_to.default_content instead
#   """Entry point for launching an IPython kernel.

# %%
'''
driver.find_element_by_xpath('//ul[@class="tab-start"]')  #就又找到 点击登录 了
'''
# Out:
# '\ndriver.find_element_by_xpath(\'//ul[@class="tab-start"]\')  #就又找到 点击登录 了\n'

# %%
###test

# %%
driver = webdriver.Chrome()

# %%
url = 'https://image.baidu.com/'

# %%
driver.get(url)

# %%
driver.find_element_by_id('kw').send_keys('风景')

# %%
driver.find_element_by_xpath('//input[@type="submit"]').click()

# %%
img_url = driver.find_elements_by_xpath('//li[@class="imgitem"]//img')[0].get_attribute('data-imgurl')
#.get_attribute('data-imgurl')

# %%
#driver.find_elements_by_xpath('//li[@class="imgitem"]')[2].get_attribute('data-imgurl')
# Out:
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# <ipython-input-3-74086239c1b0> in <module>
# ----> 1 driver.find_elements_by_xpath('//li[@class="imgitem"]')[2].get_attribute('data-imgurl')
#
# D:\Anaconda3\envs\crawler\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_elements_by_xpath(self, xpath)
#     408             elements = driver.find_elements_by_xpath("//div[contains(@class, 'foo')]")
#     409         """
# --> 410         return self.find_elements(by=By.XPATH, value=xpath)
#     411
#     412     def find_element_by_link_text(self, link_text):
#
# D:\Anaconda3\envs\crawler\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_elements(self, by, value)
#    1005         return self.execute(Command.FIND_ELEMENTS, {
#    1006             'using': by,
# -> 1007             'value': value})['value'] or []
#    1008
#    1009     @property
#
# ...

# %%
img_url
# Out:
# 'https://ss0.bdstatic.com/70cFvHSh_Q1YnxGkpoWK1HF6hhy/it/u=2311925248,2521631346&fm=26&gp=0.jpg'

# %%
img_url.rsplit('/',1)[-1]
# Out:
# 'u=2311925248,2521631346&fm=26&gp=0.jpg'

# %%
import requests
r = requests.get(img_url)

# %%
r.content
# Out:
# b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x01\x00H\x00H\x00\x00\xff\xdb\x00C\x00\x08\x06\x06\x07\x06\x05\x08\x07\x07\x07\t\t\x08\n\x0c\x14\r\x0c\x0b\x0b\x0c\x19\x12\x13\x0f\x14\x1d\x1a\x1f\x1e\x1d\x1a\x1c\x1c $.\' ",#\x1c\x1c(7),01444\x1f\'9=82<.342\xff\xdb\x00C\x01\t\t\t\x0c\x0b\x0c\x18\r\r\x182!\x1c!22222222222222222222222222222222222222222222222222\xff\xc0\x00\x11\x08\x01d\x01\xf3\x03\x01"\x00\x02\x11\x01\x03\x11\x01\xff\xc4\x00\x1b\x00\x00\x02\x03\x01\x01\x01\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x04\x05\x02\x03\x06\x00\x01\x07\xff\xc4\x00?\x10\x00\x02\x01\x03\x02\x04\x04\x04\x05\x03\x03\x03\x05\x00\x02\x03\x01\x02\x03\x00\x04\x11\x12!\x051AQ\x13"aq\x06\x14\x81\x912\xa1\xb1\xc1\xf0#B\xd1R\xe1\xf1\x07\x153\x16$br\x82C\xa24\x83\x92\xff\xc4\x00\x1a\x01\x00\x03\x01\x01\x01\x01\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x02\x03\x04\x01\x00\x05\x06\xff\xc4\x00*\x11\x00\x02\x02\x02\x02\x02\x02\x02\x02\x03\x01\x01\x01\x01\x00\x00\x01\x02\x00\x11\x03!\x121\x04A\x13"2Q\x14a\x05#qB\x813R\xf
# ...

# %%
driver.quit()
